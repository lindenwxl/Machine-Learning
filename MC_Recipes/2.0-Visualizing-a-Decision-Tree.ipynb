# %% [markdown]
# 上一节中把决策树当成一个黑盒子来处理，而在这一节会使用真实的数据来建一棵决策树，编写代码，将其可视化，并练习如何阅读决策树。这样您即可明白决策树是如何在幕后工作的。

# %% [markdown]
# Why did we use a decision tree to start? Because they have a very unique property:they're easy to read and understand.

# %% [markdown]
# ## Goals
#
# 1. Import dataset.
# 2. Train a classifier.
# 3. Predict label for new flower.
# 4. Visualize the tree.

# %%
# Import dataset
from sklearn.datasets import load_iris
iris = load_iris()
print(iris.feature_names)
print(iris.target_names)
print(iris.data[0])
print(iris.target[0])
for i in range(len(iris.target)):
    print("Example %d: label %s, featurs %s"%(i, iris.target[i],iris.data[i]))
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# ['setosa' 'versicolor' 'virginica']
# [5.1 3.5 1.4 0.2]
# 0
# Example 0: label 0, featurs [5.1 3.5 1.4 0.2]
# Example 1: label 0, featurs [4.9 3.  1.4 0.2]
# Example 2: label 0, featurs [4.7 3.2 1.3 0.2]
# Example 3: label 0, featurs [4.6 3.1 1.5 0.2]
# Example 4: label 0, featurs [5.  3.6 1.4 0.2]
# Example 5: label 0, featurs [5.4 3.9 1.7 0.4]
# Example 6: label 0, featurs [4.6 3.4 1.4 0.3]
# Example 7: label 0, featurs [5.  3.4 1.5 0.2]
# Example 8: label 0, featurs [4.4 2.9 1.4 0.2]
# Example 9: label 0, featurs [4.9 3.1 1.5 0.1]
# Example 10: label 0, featurs [5.4 3.7 1.5 0.2]
# Example 11: label 0, featurs [4.8 3.4 1.6 0.2]
# Example 12: label 0, featurs [4.8 3.  1.4 0.1]
# Example 13: label 0, featurs [4.3 3.  1.1 0.1]
# Example 14: label 0, featurs [5.8 4.  1.2 0.2]
# Example 15: label 0, featurs [5.7 4.4 1.5 0.4]
# Example 16: label 0, featurs [5.4 3.9 1.3 0.4]
# Example 17: label 0, featurs [5.1 3.5 1.4 0.3]
# Example 18: label 0, featurs [5.7 3.8 1.7 0.3]
# Example 19: label 0, featurs [5.1 3.8 1.5 0.3]
# Example 20: label 0, featurs [5.4 3.4 1.7 0.2]
# Example 21: label 0, featurs [5.1 3.7 1.5 0.4]
# Example 22: label 0, featurs [4.6 3.6 1.  0.2]
# Example 23: label 0, featurs [5.1 3.3 1.7 0.5]
# Example 24: label 0, featurs [4.8 3.4 1.9 0.2]
# Example 25: label 0, featurs [5.  3.  1.6 0.2]
# Example 26: label 0, featurs [5.  3.4 1.6 0.4]
# Example 27: label 0, featurs [5.2 3.5 1.5 0.2]
# Example 28: label 0, featurs [5.2 3.4 1.4 0.2]
# Example 29: label 0, featurs [4.7 3.2 1.6 0.2]
# Example 30: label 0, featurs [4.8 3.1 1.6 0.2]
# Example 31: label 0, featurs [5.4 3.4 1.5 0.4]
# Example 32: label 0, featurs [5.2 4.1 1.5 0.1]
# Example 33: label 0, featurs [5.5 4.2 1.4 0.2]
# Example 34: label 0, featurs [4.9 3.1 1.5 0.1]
# Example 35: label 0, featurs [5.  3.2 1.2 0.2]
# Example 36: label 0, featurs [5.5 3.5 1.3 0.2]
# Example 37: label 0, featurs [4.9 3.1 1.5 0.1]
# Example 38: label 0, featurs [4.4 3.  1.3 0.2]
# Example 39: label 0, featurs [5.1 3.4 1.5 0.2]
# Example 40: label 0, featurs [5.  3.5 1.3 0.3]
# Example 41: label 0, featurs [4.5 2.3 1.3 0.3]
# Example 42: label 0, featurs [4.4 3.2 1.3 0.2]
# Example 43: label 0, featurs [5.  3.5 1.6 0.6]
# Example 44: label 0, featurs [5.1 3.8 1.9 0.4]
# Example 45: label 0, featurs [4.8 3.  1.4 0.3]
# Example 46: label 0, featurs [5.1 3.8 1.6 0.2]
# Example 47: label 0, featurs [4.6 3.2 1.4 0.2]
# Example 48: label 0, featurs [5.3 3.7 1.5 0.2]
# Example 49: label 0, featurs [5.  3.3 1.4 0.2]
# Example 50: label 1, featurs [7.  3.2 4.7 1.4]
# Example 51: label 1, featurs [6.4 3.2 4.5 1.5]
# Example 52: label 1, featurs [6.9 3.1 4.9 1.5]
# Example 53: label 1, featurs [5.5 2.3 4.  1.3]
# Example 54: label 1, featurs [6.5 2.8 4.6 1.5]
# Example 55: label 1, featurs [5.7 2.8 4.5 1.3]
# Example 56: label 1, featurs [6.3 3.3 4.7 1.6]
# Example 57: label 1, featurs [4.9 2.4 3.3 1. ]
# Example 58: label 1, featurs [6.6 2.9 4.6 1.3]
# Example 59: label 1, featurs [5.2 2.7 3.9 1.4]
# Example 60: label 1, featurs [5.  2.  3.5 1. ]
# Example 61: label 1, featurs [5.9 3.  4.2 1.5]
# Example 62: label 1, featurs [6.  2.2 4.  1. ]
# Example 63: label 1, featurs [6.1 2.9 4.7 1.4]
# Example 64: label 1, featurs [5.6 2.9 3.6 1.3]
# Example 65: label 1, featurs [6.7 3.1 4.4 1.4]
# Example 66: label 1, featurs [5.6 3.  4.5 1.5]
# Example 67: label 1, featurs [5.8 2.7 4.1 1. ]
# Example 68: label 1, featurs [6.2 2.2 4.5 1.5]
# Example 69: label 1, featurs [5.6 2.5 3.9 1.1]
# Example 70: label 1, featurs [5.9 3.2 4.8 1.8]
# Example 71: label 1, featurs [6.1 2.8 4.  1.3]
# Example 72: label 1, featurs [6.3 2.5 4.9 1.5]
# Example 73: label 1, featurs [6.1 2.8 4.7 1.2]
# Example 74: label 1, featurs [6.4 2.9 4.3 1.3]
# Example 75: label 1, featurs [6.6 3.  4.4 1.4]
# Example 76: label 1, featurs [6.8 2.8 4.8 1.4]
# Example 77: label 1, featurs [6.7 3.  5.  1.7]
# Example 78: label 1, featurs [6.  2.9 4.5 1.5]
# Example 79: label 1, featurs [5.7 2.6 3.5 1. ]
# Example 80: label 1, featurs [5.5 2.4 3.8 1.1]
# Example 81: label 1, featurs [5.5 2.4 3.7 1. ]
# Example 82: label 1, featurs [5.8 2.7 3.9 1.2]
# Example 83: label 1, featurs [6.  2.7 5.1 1.6]
# Example 84: label 1, featurs [5.4 3.  4.5 1.5]
# Example 85: label 1, featurs [6.  3.4 4.5 1.6]
# Example 86: label 1, featurs [6.7 3.1 4.7 1.5]
# Example 87: label 1, featurs [6.3 2.3 4.4 1.3]
# Example 88: label 1, featurs [5.6 3.  4.1 1.3]
# Example 89: label 1, featurs [5.5 2.5 4.  1.3]
# Example 90: label 1, featurs [5.5 2.6 4.4 1.2]
# Example 91: label 1, featurs [6.1 3.  4.6 1.4]
# Example 92: label 1, featurs [5.8 2.6 4.  1.2]
# Example 93: label 1, featurs [5.  2.3 3.3 1. ]
# Example 94: label 1, featurs [5.6 2.7 4.2 1.3]
# Example 95: label 1, featurs [5.7 3.  4.2 1.2]
# Example 96: label 1, featurs [5.7 2.9 4.2 1.3]
# Example 97: label 1, featurs [6.2 2.9 4.3 1.3]
# Example 98: label 1, featurs [5.1 2.5 3.  1.1]
# Example 99: label 1, featurs [5.7 2.8 4.1 1.3]
# Example 100: label 2, featurs [6.3 3.3 6.  2.5]
# Example 101: label 2, featurs [5.8 2.7 5.1 1.9]
# Example 102: label 2, featurs [7.1 3.  5.9 2.1]
# Example 103: label 2, featurs [6.3 2.9 5.6 1.8]
# Example 104: label 2, featurs [6.5 3.  5.8 2.2]
# Example 105: label 2, featurs [7.6 3.  6.6 2.1]
# Example 106: label 2, featurs [4.9 2.5 4.5 1.7]
# Example 107: label 2, featurs [7.3 2.9 6.3 1.8]
# Example 108: label 2, featurs [6.7 2.5 5.8 1.8]
# Example 109: label 2, featurs [7.2 3.6 6.1 2.5]
# Example 110: label 2, featurs [6.5 3.2 5.1 2. ]
# Example 111: label 2, featurs [6.4 2.7 5.3 1.9]
# Example 112: label 2, featurs [6.8 3.  5.5 2.1]
# Example 113: label 2, featurs [5.7 2.5 5.  2. ]
# Example 114: label 2, featurs [5.8 2.8 5.1 2.4]
# Example 115: label 2, featurs [6.4 3.2 5.3 2.3]
# Example 116: label 2, featurs [6.5 3.  5.5 1.8]
# Example 117: label 2, featurs [7.7 3.8 6.7 2.2]
# Example 118: label 2, featurs [7.7 2.6 6.9 2.3]
# Example 119: label 2, featurs [6.  2.2 5.  1.5]
# Example 120: label 2, featurs [6.9 3.2 5.7 2.3]
# Example 121: label 2, featurs [5.6 2.8 4.9 2. ]
# Example 122: label 2, featurs [7.7 2.8 6.7 2. ]
# Example 123: label 2, featurs [6.3 2.7 4.9 1.8]
# Example 124: label 2, featurs [6.7 3.3 5.7 2.1]
# Example 125: label 2, featurs [7.2 3.2 6.  1.8]
# Example 126: label 2, featurs [6.2 2.8 4.8 1.8]
# Example 127: label 2, featurs [6.1 3.  4.9 1.8]
# Example 128: label 2, featurs [6.4 2.8 5.6 2.1]
# Example 129: label 2, featurs [7.2 3.  5.8 1.6]
# Example 130: label 2, featurs [7.4 2.8 6.1 1.9]
# Example 131: label 2, featurs [7.9 3.8 6.4 2. ]
# Example 132: label 2, featurs [6.4 2.8 5.6 2.2]
# Example 133: label 2, featurs [6.3 2.8 5.1 1.5]
# Example 134: label 2, featurs [6.1 2.6 5.6 1.4]
# Example 135: label 2, featurs [7.7 3.  6.1 2.3]
# Example 136: label 2, featurs [6.3 3.4 5.6 2.4]
# Example 137: label 2, featurs [6.4 3.1 5.5 1.8]
# Example 138: label 2, featurs [6.  3.  4.8 1.8]
# Example 139: label 2, featurs [6.9 3.1 5.4 2.1]
# Example 140: label 2, featurs [6.7 3.1 5.6 2.4]
# Example 141: label 2, featurs [6.9 3.1 5.1 2.3]
# Example 142: label 2, featurs [5.8 2.7 5.1 1.9]
# Example 143: label 2, featurs [6.8 3.2 5.9 2.3]
# Example 144: label 2, featurs [6.7 3.3 5.7 2.5]
# Example 145: label 2, featurs [6.7 3.  5.2 2.3]
# Example 146: label 2, featurs [6.3 2.5 5.  1.9]
# Example 147: label 2, featurs [6.5 3.  5.2 2. ]
# Example 148: label 2, featurs [6.2 3.4 5.4 2.3]
# Example 149: label 2, featurs [5.9 3.  5.1 1.8]

# %% [markdown]
# ## Testing Data
#
# - Examples used to "test" the classifier's accuracy
# - Not part of the training data
#
# Just like in programming, testing is a very important  part of ML.

# %%
# Train a classifier

import numpy as np
from sklearn.datasets import load_iris
from sklearn import tree

iris = load_iris()
test_index = [0, 50, 100]

# training data
train_target = np.delete(iris.target, test_index)
train_data = np.delete(iris.data, test_index, axis=0)

# testing data
test_target = iris.target[test_index]
test_data = iris.data[test_index]

clf = tree.DecisionTreeClassifier()
clf.fit(train_data, train_target)

print(test_target)
print(clf.predict(test_data))
# Out:
# [0 1 2]
# [0 1 2]

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn import tree
import pydotplus

# COLLECT TRAINING DATA

iris = load_iris()
test_idx = [0, 50, 100]

# training data
train_target = np.delete(iris.target, test_idx)
train_data = np.delete(iris.data, test_idx, axis=0)

# testing data
test_target = iris.target[test_idx]
test_data = iris.data[test_idx]

# TRAIN CLASSIFIER

clf = tree.DecisionTreeClassifier()
clf.fit(train_data, train_target)

# MAKE PREDICTIONS

print(test_target) #expected outcome
print(clf.predict(test_data)) #model predicted outcome

# VISUALISE THE TREE

# non-coloured version
# dot_data = tree.export_graphviz(clf, out_file=None)
# graph = pydotplus.graph_from_dot_data(dot_data)
# graph.write_pdf("iris.pdf")

dot_data = tree.export_graphviz(clf, out_file=None,
                                feature_names=iris.feature_names,
                                class_names=iris.target_names,
                                filled=True, rounded=True,
                                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_pdf("irisColoured.pdf")
# Out:
# [0 1 2]
# [0 1 2]
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-1-9bff644e6ae0> in <module>()
#      40                                 special_characters=True)
#      41 graph = pydotplus.graph_from_dot_data(dot_data)
# ---> 42 graph.write_pdf("irisColoured.pdf")
#
# D:\ProgramData\Anaconda3\lib\site-packages\pydotplus\graphviz.py in <lambda>(path, f, prog)
#    1808                 lambda path,
#    1809                 f=frmt,
# -> 1810                 prog=self.prog: self.write(path, format=f, prog=prog)
#    1811             )
#    1812
#
# D:\ProgramData\Anaconda3\lib\site-packages\pydotplus\graphviz.py in write(self, path, prog, format)
#    1916
#    1917             else:
# -> 1918                 fobj.write(self.create(prog, format))
#    1919         finally:
#    1920             if close:
#
# D:\ProgramData\Anaconda3\lib\site-packages\pydotplus\graphviz.py in create(self, prog, format)
#    1958             if self.progs is None:
#    1959                 raise InvocationException(
# -> 1960                     'GraphViz\'s executables not found')
#    1961
#    1962         if prog not in self.progs:
#
# InvocationException: GraphViz's executables not found

# %% [markdown]
# Adding it to the path or using the pip graphviz?
#
# Neither of those. Adding Library\bin\graphviz to PATH could break Spyder and Matplotlib, and the pip graphviz packages are not compatible with the graphviz package provided by conda.
#
# To be clarify even further:
#
# 1. conda install graphviz installs the C graphviz executables and libraries (e.g. the dot executable).
# 2. pip install graphviz installs one of the Python bindings for Graphviz (the one used by Dask).
# 3. conda install python-graphviz installs the same package as pip install graphviz, but patched to work with conda's Graphviz C package.
# Requiring a specific configuration in the python graphviz means that there is a tight coupling between these packages when there shouldn't be.
#
# There's no additional configuration, you just need to run
# ```
# conda install python-graphviz
# ```
# instead of
#
# ```
# pip install graphviz
#
# ```
# (as I said above).
#
#
# *How about networkx? That also uses the dot executable, right? And I think there's many more packages that do.
# I don't know, but nobody has complained about it. We'll look into it if somebody reports an issue.*

# %% [markdown]
# ##  *Choosing good features is one of your most important jobs*
